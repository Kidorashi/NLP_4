# %% [markdown]
# ## Домашнее задание

# %% [markdown]
# Основаная задача - **построить хорошую тематическую модель с интерпретируемыми топиками с помощью LDA в gensim и NMF в sklearn**.
#
#
# 1) сделайте нормализацию (если pymorphy2 работает долго используйте mystem или попробуйте установить быструю версию - `pip install pymorphy2[fast]`, можно использовать какой-то другой токенизатор);
#
# 2) добавьте нграммы (в тетрадке есть закомменченая ячейка с Phrases,  можно также попробовать другие способы построить нграммы);
#
# 3) сделайте хороший словарь (отфильтруйте слишком частотные и редкие слова, попробуйте удалить стоп-слова);
#
# 4) постройте несколько LDA моделей (переберите количество тем, можете поменять eta, alpha, passes), если получаются плохие темы, поработайте дополнительно над предобработкой и словарем;
#
# 5) для самой хорошей модели в отдельной ячейке напечатайте 3 хороших (на ваш вкус) темы;
#
# 6) между словарем и обучением модели добавьте tfidf (`gensim.models.TfidfModel(corpus, id2word=dictionary); corpus = tfidf[corpus]`);
#
# 7) повторите пункт 4 на преобразованном корпусе;
#
# 8) в отдельной ячейке опишите как изменилась модель (приведите несколько тем, которые стали лучше или хуже, или которых раньше вообще не было; можно привести значения перплексии и когерентности для обеих моделей)
#
# 9) проделайте такие же действия для NMF (образец в конце тетрадки), для построения словаря воспользуйтесь возможностями Count или Tfidf Vectorizer (попробуйте другие значение max_features, min_df, max_df, сделайте нграмы через ngram_range, если хватает памяти), попробуйте такие же количества тем
#
# 10) в отдельной ячейки напечатайте таблицу с темами лучшей NMF модели, сравните их с теми, что получились в LDA.
#
# Сохраните тетрадку с экспериментами и положите её на гитхаб, ссылку на неё укажите в форме.
#
# **Оцениваться будут главным образом пункты 5, 8 и 10. (2, 3, 2 баллов соответственно). Чтобы заработать остальные 3 балла, нужно хотя бы немного изменить мой код на промежуточных этапах (добавить что-то, указать другие параметры и т.д). **

# %%
import gensim
import json
import re
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from pymorphy2 import MorphAnalyzer
import pyLDAvis.gensim
import string
from collections import Counter
import warnings
warnings.filterwarnings("ignore")

morph = MorphAnalyzer()
# Out:
# C:\Users\1\Anaconda3\lib\site-packages\gensim\utils.py:1212: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")

# %% [markdown]
# ## Данные

# %%
#stops = set(stopwords.words('russian')) | {'gt',} - до изменения
stops = set(stopwords.words('russian')) | {'gt',} | set(stopwords.words('english'))
def remove_tags(text):
    return re.sub(r'<[^>]+>', '', text)

def normalize(words):
    norm_words = [morph.parse(word)[0].normal_form for word in words if len(set(word)) > 1]
    return norm_words

def opt_normalize(texts, top=None):
    uniq = Counter()
    for text in texts:
        uniq.update(text)
    
    norm_uniq = {word:morph.parse(word)[0].normal_form for word, _ in uniq.most_common(top)}
    
    norm_texts = []
    for text in texts:
        
        norm_words = [norm_uniq.get(word) for word in text]
        norm_words = [word for word in norm_words if word and word not in stops]
        norm_texts.append(norm_words)
        
    return norm_texts

def tokenize(text):
    words = [word.strip(string.punctuation) for word in text.split()]
    words = [word for word in words if word]
    
    return words

# %% [markdown]
# Возьмем 4 тыс статьи с Хабра. Это мало для хорошей тематической модели, но иначе у нас просто ничего не обучится за семинар.

# %%
data = open('habr_texts.txt', 'r', encoding = 'UTF-8').read()

# %% [markdown]
# В текстах есть тэги. Потрем их. Ещё токенизируем самым простым способом и нормализуем Pymorphy.

# %%
# %%time
texts = open('habr_texts.txt').read().splitlines()
texts = [tokenize(remove_tags(text.lower())) for text in texts]

# %%
# %%time
texts = open('habr_texts.txt', encoding = 'UTF-8').read().splitlines()
texts = [normalize(tokenize(text.lower())) for text in texts]

# %%
# %%time
texts = open('habr_texts.txt', encoding = 'UTF-8').read().splitlines()
texts = opt_normalize([tokenize(remove_tags(text.lower())) for text in texts], 30000)
# Out:
# Wall time: 11.6 s

# %% [markdown]
# ### Тематическое моделирование в gensim

# %%
def gensim_lda (texts, no_above=0.3, num_topics=100, passes=10, eta = 'auto', iterations=20, tfidf=False, n_gram=True):

    if n_gram:
        ph = gensim.models.Phrases(texts, scoring='npmi', threshold=0.4)
        p = gensim.models.phrases.Phraser(ph)
        texts = p[texts]

    # словарь для моделей
    dictionary = gensim.corpora.Dictionary(texts)
    dictionary.filter_extremes(no_above=no_above)
    dictionary.compactify()

    # тексты в мешки слов
    corpus = [dictionary.doc2bow(text) for text in texts]

    if tfidf:
        tfidf = gensim.models.TfidfModel(corpus, id2word=dictionary)
        corpus = tfidf[corpus]

    model = gensim.models.LdaMulticore(corpus, num_topics=num_topics,
                                       id2word=dictionary, passes=passes, eta=eta, iterations=iterations, random_state = 137)
    return model, corpus

# %%
# ?gensim.models.LdaMulticore

# %%
# %%time
lda, corpus = gensim_lda(texts)
# Out:
# Wall time: 2min 27s

# %% [markdown]
# Посмотрим на топики.

# %%
lda.print_topics()
# Out:
# [(19,
#   '0.035*"apple" + 0.013*"мобильный" + 0.008*"iphone" + 0.005*"устройство" + 0.005*"android" + 0.005*"ios" + 0.005*"технология" + 0.005*"рынок" + 0.004*"сервис" + 0.004*"смартфон"'),
#  (11,
#   '0.020*"файл" + 0.015*"сервер" + 0.008*"настройка" + 0.007*"скрипт" + 0.006*"сертификат" + 0.006*"установка" + 0.006*"добавить" + 0.005*"установить" + 0.005*"домен" + 0.005*"пароль"'),
#  (88,
#   '0.037*"автомобиль" + 0.012*"ms" + 0.011*"машина" + 0.010*"водитель" + 0.008*"дорога" + 0.007*"tesla" + 0.006*"скорость" + 0.005*"модель" + 0.005*"цена" + 0.004*"беспилотный_автомобиль"'),
#  (41,
#   '0.011*"сигнал" + 0.006*"распознавание" + 0.006*"дата-центр" + 0.005*"milliseconds" + 0.004*"тд" + 0.004*"цод" + 0.003*"объект" + 0.003*"метрика" + 0.003*"класс" + 0.003*"дц"'),
#  (27,
#   '0.012*"файл" + 0.006*"маршрутизатор" + 0.006*"electron" + 0.006*"программа" + 0.005*"lsa" + 0.005*"строка" + 0.005*"java" + 0.005*"метод" + 0.004*"номер" + 0.004*"скрипт"'),
#  (55,
#   '0.006*"учёный" + 0.006*"земля" + 0.004*"энергия" + 0.004*"температура" + 0.003*"метр" + 0.003*"аппарат" + 0.003*"планета" + 0.003*"устройство" + 0.003*"скорость" + 0.003*"мир"'),
#  (28,
#   '0.023*"as" + 0.013*"set" + 0.013*"null" + 0.009*"select" + 0.008*"from" + 0.008*"then" + 0.008*"declare" + 0.007*"int" + 0.007*"end" + 0.007*"on_go"'),
#  (90,
#   '0.006*"оптимизация" + 0.005*"while" + 0.005*"значение" + 0.004*"₽" + 0.004*"степень" + 0.004*"точка" + 0.004*"программа" + 0.003*"контроллер" + 0.003*"пять" + 0.003*"if"'),
#  (42,
#   '0.007*"атом" + 0.006*"оптимизация" + 0.005*"рендеринг" + 0.005*"if" + 0.004*"программа" + 0.004*"gpu" + 0.004*"return" + 0.004*"webassembly" + 0.004*"базовый" + 0.003*"реализация"'),
#  (48,
#   '0.009*"виртуальный_машина" + 0.009*"диск" + 0.008*"восстановление" + 0.008*"бэкап" + 0.007*"раздел" + 0.006*"файл" + 0.005*"резервный_копирование" + 0.005*"схд" + 0.004*"настройка" + 0.004*"режим"'),
#  (30,
#   '0.025*"new" + 0.023*"public" + 0.016*"return" + 0.013*"string" + 0.012*"private" + 0.011*"void" + 0.011*"public_static" + 0.010*"public_void" + 0.009*"if" + 0.008*"0"'),
#  (58,
#   '0.027*"номер" + 0.022*"звонок" + 0.017*"вызов" + 0.016*"оператор" + 0.009*"asterisk" + 0.008*"sip" + 0.007*"абонент" + 0.006*"шейдёр" + 0.006*"телефон" + 0.006*"0"'),
#  (29,
#   '0.013*"сайт" + 0.008*"клиент" + 0.006*"сервис" + 0.005*"сервер" + 0.005*"продукт" + 0.005*"доступ" + 0.004*"сеть" + 0.004*"безопасность" + 0.003*"устройство" + 0.003*"требование"'),
#  (72,
#   '0.019*"спутник" + 0.014*"ракета" + 0.012*"запуск" + 0.010*"spacex" + 0.010*"орбита" + 0.009*"космос" + 0.008*"космический" + 0.008*"пуск" + 0.008*"наса" + 0.008*"мкс"'),
#  (80,
#   '0.010*"матрица" + 0.007*"запись" + 0.006*"мб" + 0.006*"продукт" + 0.006*"объём" + 0.006*"хранение" + 0.005*"операция" + 0.005*"чтение" + 0.005*"разложение" + 0.005*"гб"'),
#  (77,
#   '0.020*"резервный_копия" + 0.011*"объём" + 0.011*"канал" + 0.010*"хостинг" + 0.010*"скорость" + 0.009*"vds" + 0.009*"ос" + 0.009*"копия" + 0.008*"максимальный" + 0.007*"интернет"'),
#  (35,
#   '0.020*"усилитель" + 0.009*"обратный_связь" + 0.008*"частота" + 0.006*"сигнал" + 0.006*"коэффициент_усиление" + 0.005*"оу" + 0.004*"режим" + 0.004*"транзистор" + 0.004*"диск" + 0.003*"искажение"'),
#  (32,
#   '0.021*"хакатон" + 0.007*"железо" + 0.006*"разгон" + 0.005*"torch" + 0.004*"дробный" + 0.004*"участник" + 0.003*"российский" + 0.003*"сообщество" + 0.003*"модель" + 0.003*"продукт"'),
#  (46,
#   '0.022*"пакет" + 0.011*"сеть" + 0.010*"dpdk" + 0.008*"виртуальный" + 0.007*"робот" + 0.006*"задержка" + 0.006*"таблица" + 0.005*"модуль" + 0.005*"linux" + 0.005*"пространство"'),
#  (50,
#   '0.067*"камера" + 0.018*"видео" + 0.012*"книга" + 0.008*"управление" + 0.007*"дизайнер" + 0.006*"экран" + 0.006*"дизайн" + 0.005*"интерфейс" + 0.004*"design" + 0.004*"устройство"')]

# %%
import numpy as np

# %%
# ?lda.log_perplexity

# %%
lda.log_perplexity(corpus[:2000], total_docs=100)
# Out:
# -19.665877118389492

# %% [markdown]
# В целом, топики уже достаточно похожи на правду.
# Если посмотреть на некоторые списки, то можно увидеть в топиках большое количество частей кода (что логично, это же Хабр). Это почти все слова на латинице, но полностью английский удалять нельзя, чтобы не исчезли важные термины, которым может быть посвящена статья. Поэтому просто очистим тексты от частотных английских слов и слов короче 5и букв.

# %%
texts = open('habr_texts.txt', encoding = 'UTF-8').read().splitlines()
texts = opt_normalize([tokenize(remove_tags(text.lower())) for text in texts], 30000)

# %%
for text in texts:
    for word in text:
        if len(word) <=4:
            text.remove(word)

# %%
# %%time
lda, corpus = gensim_lda(texts)
# Out:
# Wall time: 2min

# %%
lda.print_topics()
# Out:
# [(88,
#   '0.006*"временной" + 0.006*"попробовать" + 0.005*"находить" + 0.004*"задание" + 0.004*"директория" + 0.004*"параметр" + 0.004*"посмотреть" + 0.004*"2" + 0.004*"запустить" + 0.004*"модель"'),
#  (44,
#   '0.069*"модуль" + 0.012*"контроллер" + 0.007*"добавить" + 0.007*"страница" + 0.006*"ответ" + 0.006*"зависимость" + 0.005*"сообщение" + 0.005*"метод" + 0.005*"запрос" + 0.005*"загрузка"'),
#  (8,
#   '0.048*"0" + 0.033*"1" + 0.018*"else" + 0.017*"2" + 0.016*"0_0" + 0.014*"4" + 0.013*"return" + 0.013*"int" + 0.011*"5" + 0.010*"3"'),
#  (35,
#   '0.014*"безопасность" + 0.013*"атака" + 0.011*"доступ" + 0.010*"защита" + 0.008*"клиент" + 0.008*"интернет" + 0.008*"сервер" + 0.007*"оператор" + 0.007*"сервис" + 0.006*"злоумышленник"'),
#  (77,
#   '0.010*"метка" + 0.009*"маршрут" + 0.009*"пакет" + 0.009*"маршрутизатор" + 0.008*"значение" + 0.007*"трафик" + 0.006*"точка" + 0.006*"данный" + 0.005*"протокол" + 0.005*"интерфейс"'),
#  (49,
#   '0.018*"значение" + 0.012*"точка" + 0.011*"алгоритм" + 0.009*"элемент" + 0.008*"массив" + 0.008*"строка" + 0.006*"1" + 0.006*"координата" + 0.005*"операция" + 0.005*"множество"'),
#  (37,
#   '0.011*"вкладка" + 0.011*"браузер" + 0.006*"список" + 0.005*"квеста" + 0.004*"screen" + 0.004*"реклама" + 0.004*"virtuozzo" + 0.004*"терминал" + 0.004*"открытый" + 0.004*"adblock"'),
#  (25,
#   '0.010*"шорткат" + 0.009*"карта" + 0.007*"алгоритм" + 0.005*"спрайт" + 0.005*"переменный" + 0.005*"связь" + 0.005*"структура" + 0.004*"семантический" + 0.004*"расстояние" + 0.004*"корабль"'),
#  (57,
#   '0.042*"устройство" + 0.010*"передача" + 0.007*"протокол" + 0.007*"канал" + 0.007*"доступ" + 0.007*"скорость" + 0.007*"стандарт" + 0.006*"управление" + 0.006*"беспроводный" + 0.005*"поток"'),
#  (12,
#   '0.013*"метод" + 0.012*"фотография" + 0.007*"объект" + 0.007*"кортеж" + 0.007*"источник" + 0.006*"закон" + 0.006*"money" + 0.005*"callback" + 0.005*"панорама" + 0.004*"изображение"'),
#  (98,
#   '0.006*"список" + 0.006*"указатель" + 0.006*"процессор" + 0.005*"программа" + 0.005*"слово" + 0.004*"scala" + 0.004*"компилятор" + 0.004*"поток" + 0.004*"code.org" + 0.004*"кристалл"'),
#  (0,
#   '0.049*"слово" + 0.025*"символ" + 0.016*"буква" + 0.006*"словарь" + 0.006*"программа" + 0.006*"предложение" + 0.005*"метод" + 0.005*"текст" + 0.004*"цифра" + 0.004*"изображение"'),
#  (13,
#   '0.054*"камера" + 0.020*"видео" + 0.009*"сервер" + 0.008*"покупка" + 0.007*"сервис" + 0.006*"google" + 0.004*"доступ" + 0.004*"интернет" + 0.004*"актор" + 0.004*"2"'),
#  (4,
#   '0.012*"fortran" + 0.009*"отчёт" + 0.007*"название" + 0.006*"emdrive" + 0.006*"кнопка" + 0.006*"массив" + 0.005*"физика" + 0.005*"print" + 0.005*"двигатель" + 0.005*"клавиатура"'),
#  (74,
#   '0.023*"return" + 0.007*"программа" + 0.007*"0" + 0.007*"драйвер" + 0.006*"public_function" + 0.005*"значение" + 0.005*"пакет" + 0.005*"память" + 0.005*"библиотека" + 0.004*"1"'),
#  (66,
#   '0.009*"кластер" + 0.008*"хранение" + 0.007*"сервис" + 0.006*"хранилище" + 0.006*"облако" + 0.006*"инфраструктура" + 0.006*"технология" + 0.006*"управление" + 0.005*"сервер" + 0.005*"облачный"'),
#  (18,
#   '0.021*"протез" + 0.021*"университет_итмый" + 0.019*"consul" + 0.008*"университет" + 0.004*"haproxy" + 0.004*"открытый_дверь" + 0.004*"поступать" + 0.003*"доверие" + 0.003*"кафедра" + 0.003*"сервис"'),
#  (32,
#   '0.006*"вконтакте" + 0.006*"ericsson" + 0.005*"универсальность" + 0.005*"протокол" + 0.005*"токен" + 0.005*"матрица" + 0.004*"секретный" + 0.004*"аккаунт" + 0.004*"страница" + 0.004*"список"'),
#  (58,
#   '0.019*"видеокарта" + 0.014*"процессор" + 0.011*"ребро" + 0.007*"оптимизация" + 0.007*"nvidia" + 0.007*"частота" + 0.006*"geforce" + 0.005*"железо" + 0.005*"i7" + 0.005*"точка"'),
#  (38,
#   '0.025*"контейнер" + 0.015*"конфигурация" + 0.015*"docker" + 0.013*"репозиторий" + 0.009*"настройка" + 0.009*"изменение" + 0.009*"сервер" + 0.009*"сервис" + 0.008*"коммит" + 0.008*"директория"')]

# %%
lda.log_perplexity(corpus[:2000], total_docs=100)
# Out:
# -20.13378572284271

# %% [markdown]
# Построим нескролько LDA моделей.
# Будем рандомно изменять три параметра: passes, eta и num_topics.

# %%
# %%time
lda, corpus = gensim_lda(texts, eta = 0.01, num_topics = 50)
print(lda.log_perplexity(corpus[:2000], total_docs=100))
# Out:
# -30.559156468058315
# Wall time: 1min 55s

# %%
lda.print_topics(10)
# Out:
# [(42,
#   '0.013*"устройство" + 0.010*"intel" + 0.009*"linux" + 0.009*"компьютер" + 0.008*"программа" + 0.007*"память" + 0.006*"производительность" + 0.006*"процессор" + 0.006*"поддержка" + 0.005*"технология"'),
#  (43,
#   '0.017*"сервер" + 0.013*"настройка" + 0.009*"виртуальный_машина" + 0.008*"восстановление" + 0.007*"бэкап" + 0.006*"резервный_копирование" + 0.006*"отчёт" + 0.006*"номер" + 0.005*"доступ" + 0.005*"настроить"'),
#  (28,
#   '0.031*"точка" + 0.019*"объект" + 0.019*"карта" + 0.017*"координата" + 0.016*"текстура" + 0.012*"изображение" + 0.010*"алгоритм" + 0.007*"линия" + 0.006*"пиксель" + 0.006*"шейдёр"'),
#  (32,
#   '0.015*"студент" + 0.011*"makerbot" + 0.009*"университет_итмый" + 0.009*"экзамен" + 0.007*"знание" + 0.007*"город" + 0.006*"программирование" + 0.006*"материал" + 0.006*"университет" + 0.006*"олимпиада"'),
#  (15,
#   '0.020*"yahoo" + 0.015*"цифра" + 0.014*"биткоина" + 0.010*"openstack" + 0.010*"значение" + 0.008*"стрелка" + 0.007*"fedora" + 0.006*"fujitsu" + 0.006*"парсер" + 0.005*"привести"'),
#  (26,
#   '0.005*"письмо" + 0.005*"материал" + 0.005*"аппарат" + 0.004*"космический" + 0.004*"спутник" + 0.004*"космос" + 0.004*"поверхность" + 0.004*"доход" + 0.004*"миссия" + 0.004*"земля"'),
#  (46,
#   '0.010*"книга" + 0.008*"программирование" + 0.006*"программа" + 0.005*"читать" + 0.005*"слово" + 0.004*"что-то" + 0.004*"компьютер" + 0.004*"ребёнок" + 0.004*"какой-то" + 0.004*"понимать"'),
#  (23,
#   '0.007*"сотрудник" + 0.005*"программист" + 0.004*"жизнь" + 0.004*"рабочий" + 0.003*"специалист" + 0.003*"какой-то" + 0.003*"что-то" + 0.003*"менеджер" + 0.003*"заниматься" + 0.003*"знание"'),
#  (13,
#   '0.060*"камера" + 0.011*"видео" + 0.008*"сервер" + 0.007*"устройство" + 0.007*"сканирование" + 0.006*"покупка" + 0.006*"управление" + 0.005*"сервис" + 0.005*"google" + 0.005*"доступ"'),
#  (38,
#   '0.013*"сервер" + 0.011*"контейнер" + 0.011*"настройка" + 0.009*"конфигурация" + 0.008*"server" + 0.007*"docker" + 0.006*"установка" + 0.006*"установить" + 0.006*"сервис" + 0.006*"репозиторий"')]

# %%
# %%time
lda, corpus = gensim_lda(texts, eta = 0.5, num_topics = 200, passes = 5)
print(lda.log_perplexity(corpus[:2000], total_docs=100))
# Out:
# -18.982029105899358
# Wall time: 2min 14s

# %%
lda.print_topics(10)
# Out:
# [(113,
#   '0.005*"лампа" + 0.001*"вместо" + 0.001*"индекс_цветопередача" + 0.001*"elixir" + 0.001*"рубль" + 0.001*"продавать" + 0.001*"death" + 0.000*"остаться" + 0.000*"магазин" + 0.000*"лампочка"'),
#  (136,
#   '0.003*"станок" + 0.001*"jarvis" + 0.001*"гитхаб" + 0.001*"цукерберг" + 0.001*"коммит" + 0.001*"yum_install" + 0.001*"starttime" + 0.001*"объект" + 0.001*"schneider_electric" + 0.000*"библиотека"'),
#  (134,
#   '0.009*"сигнал" + 0.006*"учёный" + 0.006*"исследование" + 0.003*"метод" + 0.003*"вектор" + 0.003*"частота" + 0.003*"область" + 0.003*"пациент" + 0.003*"значение" + 0.003*"группа"'),
#  (106,
#   '0.007*"клиент" + 0.004*"продукт" + 0.004*"сотрудник" + 0.004*"сервис" + 0.004*"рынок" + 0.003*"что-то" + 0.003*"какой-то" + 0.003*"бизнес" + 0.003*"доклад" + 0.003*"заниматься"'),
#  (70,
#   '0.029*"робот" + 0.010*"земля" + 0.009*"астероид" + 0.008*"планета" + 0.005*"поверхность" + 0.004*"аппарат" + 0.004*"орбита" + 0.003*"планет" + 0.003*"учёный" + 0.003*"венера"'),
#  (183,
#   '0.002*"кальций" + 0.002*"universe" + 0.002*"openai" + 0.002*"здание" + 0.001*"метод" + 0.001*"анализ" + 0.001*"ветер" + 0.001*"«лахта_центра»" + 0.001*"город" + 0.001*"обучение_подкрепление"'),
#  (139,
#   '0.002*"солнце" + 0.001*"столетие" + 0.001*"температура" + 0.001*"розетка" + 0.001*"отопление" + 0.001*"разряд" + 0.001*"планета" + 0.001*"объект" + 0.001*"орбита" + 0.001*"гравитация"'),
#  (34,
#   '0.005*"матрица" + 0.003*"rails" + 0.002*"разложение" + 0.002*"gt;&gt;&gt" + 0.002*"мелодия" + 0.001*"вектор" + 0.001*"песнь" + 0.001*"упоминание" + 0.001*"personal" + 0.001*"показать"'),
#  (178,
#   '0.012*"технология" + 0.006*"область" + 0.004*"виртуальный_реальность" + 0.004*"развитие" + 0.003*"компьютер" + 0.003*"блокчейн" + 0.003*"исследование" + 0.003*"рынок" + 0.003*"машина" + 0.003*"существовать"'),
#  (98,
#   '0.001*"волокно" + 0.001*"expression" + 0.001*"return" + 0.001*"погода" + 0.001*"список" + 0.001*"toolchain" + 0.001*"operations" + 0.001*"jan" + 0.001*"std::string" + 0.001*"устройство"')]

# %%
# %%time
lda, corpus = gensim_lda(texts, eta = 1, num_topics = 50, passes = 5)
print(lda.log_perplexity(corpus[:2000], total_docs=100))
# Out:
# -17.707551236691305
# Wall time: 1min 21s

# %%
lda.print_topics(10)
# Out:
# [(35,
#   '0.005*"клиент" + 0.005*"сервис" + 0.005*"сервер" + 0.005*"доступ" + 0.004*"безопасность" + 0.004*"сотрудник" + 0.003*"ресурс" + 0.003*"атака" + 0.003*"организация" + 0.003*"защита"'),
#  (7,
#   '0.002*"нагрузка" + 0.002*"сервер" + 0.001*"устройство" + 0.001*"скорость" + 0.001*"redmine" + 0.001*"технология" + 0.001*"сервис" + 0.001*"запрос" + 0.001*"болезнь" + 0.001*"модель"'),
#  (38,
#   '0.006*"контейнер" + 0.004*"сервер" + 0.004*"docker" + 0.003*"server" + 0.003*"настройка" + 0.003*"конфигурация" + 0.002*"параметр" + 0.002*"директория" + 0.002*"изменение" + 0.002*"hadoop"'),
#  (10,
#   '0.003*"папка" + 0.002*"установка" + 0.002*"токен" + 0.002*"итератор" + 0.002*"сервер" + 0.001*"запустить" + 0.001*"список" + 0.001*"сборка" + 0.001*"ссылка" + 0.001*"установить"'),
#  (46,
#   '0.008*"книга" + 0.005*"программирование" + 0.003*"читать" + 0.003*"программа" + 0.003*"слово" + 0.003*"какой-то" + 0.002*"что-то" + 0.002*"pocketbook" + 0.002*"компьютер" + 0.002*"ребёнок"'),
#  (3,
#   '0.008*"игрок" + 0.004*"доклад" + 0.004*"продукт" + 0.003*"какой-то" + 0.003*"конференция" + 0.003*"игра" + 0.003*"что-то" + 0.003*"рынок" + 0.003*"история" + 0.002*"играть"'),
#  (11,
#   '0.005*"ошибка" + 0.003*"анализатор" + 0.003*"поток" + 0.003*"значение" + 0.002*"fortran" + 0.002*"какой-то" + 0.002*"pvs-studio" + 0.002*"указатель" + 0.002*"массив" + 0.002*"return"'),
#  (43,
#   '0.006*"бэкап" + 0.005*"резервный_копирование" + 0.004*"восстановление" + 0.004*"сервер" + 0.003*"настройка" + 0.002*"виртуальный_машина" + 0.002*"резервный_копия" + 0.002*"veeam" + 0.002*"server" + 0.002*"полный"'),
#  (47,
#   '0.006*"учёный" + 0.004*"энергия" + 0.003*"исследование" + 0.003*"пациент" + 0.003*"клетка" + 0.003*"животное" + 0.003*"организм" + 0.003*"заболевание" + 0.003*"болезнь" + 0.002*"лечение"'),
#  (32,
#   '0.003*"makerbot" + 0.001*"метод" + 0.001*"технология" + 0.001*"какой-то" + 0.001*"собственный" + 0.001*"страница" + 0.001*"класс" + 0.000*"сервис" + 0.000*"mother" + 0.000*"ошибка"')]

# %%
# %%time
lda, corpus = gensim_lda(texts, num_topics = 150, passes = 20)
print(lda.log_perplexity(corpus[:2000], total_docs=100))
# Out:
# -20.33758031022881
# Wall time: 4min 47s

# %%
lda.print_topics(10)
# Out:
# [(55,
#   '0.036*"доклад" + 0.035*"участник" + 0.028*"конференция" + 0.011*"рассказать" + 0.010*"блокчейн" + 0.010*"мероприятие" + 0.009*"выступление" + 0.008*"участие" + 0.008*"спикер" + 0.007*"встреча"'),
#  (81,
#   '0.025*"блокировка" + 0.007*"конкурс" + 0.007*"критический_секция" + 0.006*"лекция" + 0.005*"калькулятор" + 0.004*"трансляция" + 0.004*"материал" + 0.004*"ip" + 0.004*"байт" + 0.004*"круглый_скобка"'),
#  (45,
#   '0.024*"регистр" + 0.022*"angular" + 0.013*"трекинг" + 0.012*"значение" + 0.008*"webassembly" + 0.007*"инструкция" + 0.007*"изменение" + 0.005*"быстрый" + 0.005*"номер" + 0.005*"https"'),
#  (22,
#   '0.024*"email" + 0.014*"begin" + 0.010*"university" + 0.009*"algorithms" + 0.007*"recipients" + 0.007*"length" + 0.006*"introduction" + 0.006*"весна" + 0.006*"youtube" + 0.006*"quoted_identifier_create"'),
#  (50,
#   '0.063*"автомобиль" + 0.033*"машина" + 0.019*"водитель" + 0.010*"безопасность" + 0.009*"дорога" + 0.009*"управление" + 0.008*"технология" + 0.008*"устройство" + 0.007*"режим" + 0.007*"беспилотный_автомобиль"'),
#  (93,
#   '0.015*"настройка" + 0.011*"скрипт" + 0.009*"список" + 0.008*"пакет" + 0.008*"добавить" + 0.008*"установка" + 0.008*"установить" + 0.007*"адрес" + 0.007*"параметр" + 0.007*"выбрать"'),
#  (134,
#   '0.014*"цвета" + 0.014*"символ" + 0.009*"шрифт" + 0.007*"сигнал" + 0.007*"activity" + 0.006*"текст" + 0.006*"действие" + 0.005*"элемент" + 0.005*"выбрать" + 0.005*"класс"'),
#  (144,
#   '0.027*"страна" + 0.017*"город" + 0.015*"россия" + 0.008*"firebase" + 0.008*"интернет" + 0.006*"местный" + 0.006*"шасси" + 0.006*"мобильный" + 0.006*"связь" + 0.004*"житель"'),
#  (71,
#   '0.020*"сервис" + 0.012*"python" + 0.011*"сервер" + 0.010*"инструмент" + 0.008*"плагин" + 0.007*"server" + 0.006*"поддержка" + 0.006*"скрипт" + 0.005*"релиз" + 0.005*"документация"'),
#  (125,
#   '0.058*"вселенная" + 0.034*"галактика" + 0.011*"звезда" + 0.010*"скорость" + 0.010*"миллиард" + 0.009*"теория" + 0.008*"наблюдение" + 0.008*"tarantool" + 0.008*"материя" + 0.008*"тёмный_энергия"')]

# %% [markdown]
# Лучше всего отработала модель [eta = 0.01, num_topics = 50].
# Лучшие топики модели:
# (13, '0.060*"камера" + 0.011*"видео" + 0.008*"сервер" + 0.007*"устройство" + 0.007*"сканирование" + 0.006*"покупка" + 0.006*"управление" + 0.005*"сервис" + 0.005*"google" + 0.005*"доступ"')
# (42, '0.013*"устройство" + 0.010*"intel" + 0.009*"linux" + 0.009*"компьютер" + 0.008*"программа" + 0.007*"память" + 0.006*"производительность" + 0.006*"процессор" + 0.006*"поддержка" + 0.005*"технология"')
# (28, '0.031*"точка" + 0.019*"объект" + 0.019*"карта" + 0.017*"координата" + 0.016*"текстура" + 0.012*"изображение" + 0.010*"алгоритм" + 0.007*"линия" + 0.006*"пиксель" + 0.006*"шейдёр"')

# %% [markdown]
# Добавим tfidf.

# %%
# %%time
lda, corpus = gensim_lda(texts, eta = 0.01, num_topics = 50, tfidf=True)
print(lda.log_perplexity(corpus[:2000], total_docs=100))
# Out:
# -113.10003378914782
# Wall time: 3min 45s

# %%
lda.print_topics(10)
# Out:
# [(0,
#   '0.010*"видеокарта" + 0.008*"education" + 0.006*"юпитер" + 0.005*"ludum" + 0.005*"nvidia" + 0.005*"samsung_galaxy" + 0.004*"operations" + 0.004*"частота_ггц" + 0.003*"reads" + 0.003*"bluemix"'),
#  (12,
#   '0.005*"предупреждение_pvs-studio" + 0.005*"flussonic" + 0.004*"колонна" + 0.004*"baidu" + 0.004*"прямоугольник" + 0.003*"unreal_engine" + 0.003*"2d" + 0.003*"выпуск_подкаста" + 0.003*"weather" + 0.003*"всплывать"'),
#  (17,
#   '0.012*"ботнет" + 0.010*"infiniband" + 0.009*"mediatek" + 0.008*"mirai" + 0.007*"наушник" + 0.007*"fujitsu" + 0.006*"gt;&gt;&gt" + 0.006*"эксплойт" + 0.005*"обследование" + 0.005*"расширение_вселенная"'),
#  (13,
#   '0.017*"pvs-studio" + 0.008*"анализатор" + 0.005*"working" + 0.005*"param" + 0.004*"анализатор_pvs-studio" + 0.004*"config" + 0.004*"cmake" + 0.004*"await" + 0.004*"returns" + 0.004*"clock"'),
#  (8,
#   '0.007*"pebble" + 0.006*"protected_function" + 0.005*"литий" + 0.005*"фонарик" + 0.004*"makerbot" + 0.004*"fixedupdate" + 0.004*"dolby_atmos" + 0.004*"rxjava" + 0.004*"slave" + 0.004*"плутон"'),
#  (44,
#   '0.006*"биллинга" + 0.005*"алиас" + 0.005*"центр_галактика" + 0.005*"selector" + 0.004*"дискета" + 0.004*"export_class" + 0.004*"changes" + 0.004*"employee" + 0.003*"проигрыватель" + 0.003*"another"'),
#  (39,
#   '0.006*"кристалл" + 0.006*"юрист" + 0.006*"ethereum" + 0.005*"технология_блокчейн" + 0.005*"космический_аппарат" + 0.005*"соискатель" + 0.005*"роскомнадзор" + 0.005*"билет" + 0.004*"dart" + 0.004*"биткойна"'),
#  (31,
#   '0.007*"delphi" + 0.005*"exten_exten" + 0.005*"кларк" + 0.004*"delivery" + 0.004*"троян" + 0.004*"pipeline" + 0.004*"deprecated" + 0.004*"sketch" + 0.003*"explain" + 0.003*"судок"'),
#  (5,
#   '0.009*"qualcomm" + 0.007*"samsung" + 0.007*"средний_зарплата" + 0.006*"вадим" + 0.004*"writing" + 0.004*"philips" + 0.003*"ericsson" + 0.003*"computer_programming" + 0.003*"mathematics" + 0.003*"выступление_спикер"'),
#  (32,
#   '0.010*"препарат" + 0.009*"emdrive" + 0.006*"pokemon" + 0.005*"индуктивность" + 0.004*"микросхема" + 0.004*"color" + 0.004*"импульс" + 0.004*"postcss" + 0.004*"профессор_университет" + 0.004*"github_pages"')]

# %%
# %%time
lda, corpus = gensim_lda(texts, eta = 0.5, num_topics = 200, passes = 5, tfidf=True)
print(lda.log_perplexity(corpus[:2000], total_docs=100))
# Out:
# -19.329379318414293
# Wall time: 2min 55s

# %%
lda.print_topics(10)
# Out:
# [(113,
#   '0.000*"стекло" + 0.000*"препарат" + 0.000*"пациент" + 0.000*"робот" + 0.000*"tesla" + 0.000*"математика" + 0.000*"сознание" + 0.000*"автомобиль" + 0.000*"death" + 0.000*"доказательство"'),
#  (136,
#   '0.000*"автомобиль" + 0.000*"водитель" + 0.000*"квеста" + 0.000*"javascript" + 0.000*"коммит" + 0.000*"декабрь" + 0.000*"проведение" + 0.000*"yield_return" + 0.000*"watson" + 0.000*"starcraft"'),
#  (134,
#   '0.000*"игрок" + 0.000*"nokia" + 0.000*"apple" + 0.000*"firebase" + 0.000*"сигнал" + 0.000*"патент" + 0.000*"гарнитур" + 0.000*"drone" + 0.000*"смартфон" + 0.000*"игровой"'),
#  (106,
#   '0.000*"javascript" + 0.000*"браузер" + 0.000*"нейрон" + 0.000*"react" + 0.000*"сервер" + 0.000*"устройство" + 0.000*"модель" + 0.000*"return" + 0.000*"google" + 0.000*"программа"'),
#  (70,
#   '0.000*"удовольствие_ответить" + 0.000*"web-интерфейс" + 0.000*"контрольный_точка" + 0.000*"asterisk" + 0.000*"позади" + 0.000*"следование" + 0.000*"земной" + 0.000*"сертификат" + 0.000*"продукт" + 0.000*"плеер"'),
#  (183,
#   '0.000*"биткоина" + 0.000*"textview" + 0.000*"метод" + 0.000*"изображение" + 0.000*"cgrect" + 0.000*"frames" + 0.000*"локализация" + 0.000*"public_context" + 0.000*"alarm" + 0.000*"сегментация"'),
#  (139,
#   '0.000*"клавиатура" + 0.000*"person" + 0.000*"typescript" + 0.000*"чувство" + 0.000*"отопление" + 0.000*"hyperx" + 0.000*"образование" + 0.000*"падение" + 0.000*"температура" + 0.000*"mozilla_firefox"'),
#  (34,
#   '0.000*"модульный_тестирование" + 0.000*"комната" + 0.000*"будильник" + 0.000*"yum_install" + 0.000*"rails" + 0.000*"hololens" + 0.000*"книга" + 0.000*"gt;&gt;&gt" + 0.000*"замок" + 0.000*"тестирование"'),
#  (178,
#   '0.000*"gitlab" + 0.000*"раздел" + 0.000*"reactos" + 0.000*"энергия" + 0.000*"docker-compose" + 0.000*"вселенная" + 0.000*"ветка" + 0.000*"зашифровать" + 0.000*"скрам" + 0.000*"флешек"'),
#  (98,
#   '0.000*"волокно" + 0.000*"b_b" + 0.000*"список" + 0.000*"родной" + 0.000*"браузер" + 0.000*"function" + 0.000*"intel" + 0.000*"элемент" + 0.000*"текстура" + 0.000*"итератор"')]

# %%
# %%time
lda, corpus = gensim_lda(texts, eta = 1, num_topics = 50, passes = 5, tfidf=True)
print(lda.log_perplexity(corpus[:2000], total_docs=100))
# Out:
# -17.39506433241136
# Wall time: 2min 14s

# %%
lda.print_topics(10)
# Out:
# [(35,
#   '0.000*"устройство" + 0.000*"сборка" + 0.000*"пакет" + 0.000*"google" + 0.000*"операция" + 0.000*"номер" + 0.000*"калькулятор" + 0.000*"image" + 0.000*"электронный" + 0.000*"поддержка"'),
#  (7,
#   '0.000*"public" + 0.000*"num" + 0.000*"инструментарий" + 0.000*"медаль" + 0.000*"дата-центр" + 0.000*"semantic" + 0.000*"спутник" + 0.000*"react" + 0.000*"сервер" + 0.000*"bootstrap"'),
#  (38,
#   '0.000*"выгрузить" + 0.000*"резервный_копирование" + 0.000*"линейный" + 0.000*"0" + 0.000*"восстановление" + 0.000*"физика" + 0.000*"резервный_копия" + 0.000*"станция" + 0.000*"компонент" + 0.000*"виртуальный_машина"'),
#  (10,
#   '0.000*"устройство" + 0.000*"windows" + 0.000*"доклад" + 0.000*"усилитель" + 0.000*"сервер" + 0.000*"сообщение" + 0.000*"игрок" + 0.000*"книга" + 0.000*"linux" + 0.000*"видео"'),
#  (46,
#   '0.000*"спутник" + 0.000*"орбита" + 0.000*"земля" + 0.000*"станция" + 0.000*"планета" + 0.000*"ракета" + 0.000*"аппарат" + 0.000*"миссия" + 0.000*"астероид" + 0.000*"учёный"'),
#  (3,
#   '0.000*"tesla" + 0.000*"1_1" + 0.000*"игрок" + 0.000*"вакансия" + 0.000*"клиент" + 0.000*"veeam" + 0.000*"миссия" + 0.000*"отчёт" + 0.000*"камера" + 0.000*"ребёнок"'),
#  (11,
#   '0.000*"дата-центр" + 0.000*"издательство" + 0.000*"nginx" + 0.000*"ноябрь_19:00" + 0.000*"оборудование" + 0.000*"05" + 0.000*"конференция" + 0.000*"мастер-класс" + 0.000*"пароль" + 0.000*"скрам"'),
#  (43,
#   '0.000*"сертификат" + 0.000*"begin" + 0.000*"запрос" + 0.000*"nvarchar(255" + 0.000*"quoted_identifier_create" + 0.000*"имя_базы_дать_ansi_nulls" + 0.000*"server" + 0.000*"задание" + 0.000*"спектрометр" + 0.000*"сервер"'),
#  (47,
#   '0.000*"камера" + 0.000*"земля" + 0.000*"программа" + 0.000*"клетка" + 0.000*"животное" + 0.000*"учёный" + 0.000*"сервер" + 0.000*"видео" + 0.000*"ткань" + 0.000*"продукт"'),
#  (32,
#   '0.000*"color" + 0.000*"доклад" + 0.000*"apple" + 0.000*"учёный" + 0.000*"опрос" + 0.000*"лампа" + 0.000*"автомобиль" + 0.000*"вулкан" + 0.000*"postcss" + 0.000*"научный"')]

# %%
# %%time
lda, corpus = gensim_lda(texts, num_topics = 150, passes = 20, tfidf=True)
print(lda.log_perplexity(corpus[:2000], total_docs=100))
# Out:
# -91.95206649599642
# Wall time: 7min 21s

# %%
lda.print_topics(10)
# Out:
# [(55,
#   '0.007*"resharper" + 0.006*"compute" + 0.006*"identifier" + 0.005*"backlog" + 0.004*"feature" + 0.004*"cordova" + 0.004*"navigation" + 0.003*"snapshot" + 0.003*"subscription" + 0.003*"неограниченный"'),
#  (81,
#   '0.008*"акустический_система" + 0.006*"лабиринт" + 0.006*"аудиосистема" + 0.006*"аудиомания" + 0.005*"наушник" + 0.005*"коэффициент_усиление" + 0.003*"выходной_мощность" + 0.003*"apk" + 0.003*"вебинар" + 0.002*"усилитель"'),
#  (45,
#   '0.014*"микросервис" + 0.007*"такси" + 0.005*"brocade" + 0.004*"systemjs" + 0.004*"notes" + 0.003*"background-size" + 0.003*"results" + 0.003*"emc" + 0.003*"phoenix" + 0.003*"цифровой_экономика"'),
#  (22,
#   '0.007*"лекция_лекция" + 0.005*"email_маркетинг" + 0.004*"кларк" + 0.004*"девяносто" + 0.003*"кодек" + 0.003*"контрольный_сумма" + 0.002*"р_р" + 0.002*"№" + 0.002*"чарльз" + 0.002*"гуглить"'),
#  (50,
#   '0.013*"беспилотный_автомобиль" + 0.009*"positive_technologies" + 0.005*"беспилотный" + 0.004*"mortal_kombat" + 0.004*"begin_begin" + 0.004*"бесплатный_билет" + 0.004*"фабрика" + 0.003*"procedure_begin" + 0.003*"option" + 0.003*"sequence"'),
#  (93,
#   '0.014*"pocketbook" + 0.004*"энергоснабжение" + 0.003*"частотный_канал" + 0.003*"середина_век" + 0.003*"служба_эксплуатация" + 0.002*"мэтью" + 0.002*"facebook_вконтакте" + 0.002*"набирать_оборот" + 0.002*"крупный_телекоммуникационный" + 0.002*"pearl"'),
#  (134,
#   '0.009*"ivideon" + 0.003*"архивация" + 0.003*"мбит/секунда" + 0.002*"художественный" + 0.002*"операция_ввод-вывод" + 0.002*"16gb" + 0.002*"твердотельный_накопитель" + 0.002*"гнездо" + 0.002*"выложить_github" + 0.001*"дарить"'),
#  (144,
#   '0.008*"белка" + 0.006*"vk.com" + 0.006*"sha-1" + 0.006*"«яндекс»" + 0.006*"белок" + 0.005*"растение" + 0.005*"авторский_право" + 0.005*"животное" + 0.005*"рф" + 0.005*"width"'),
#  (71,
#   '0.005*"гарри" + 0.005*"spark" + 0.005*"report" + 0.004*"wechat" + 0.004*"по-новому" + 0.004*"иллюзия" + 0.004*"«этота" + 0.004*"skylake" + 0.004*"gateway" + 0.003*"конструирование"'),
#  (125,
#   '0.007*"19:00" + 0.005*"покер" + 0.002*"вращение_земля" + 0.002*"официально_зарегистрировать" + 0.001*"приятный_мелочь" + 0.001*"неполный" + 0.001*"lt;/body&gt" + 0.001*"пятница" + 0.001*"добро" + 0.001*"настроение"')]

# %% [markdown]
# Результаты лучшей модели сильно ухудшились. Да и в остальных моделях результаты лучше не стали. Появилось много слов, которые явно не относятся к топикам. Некоторого мусора не было даже при самом первом запуске.

# %% [markdown]
# ### Разложение матриц в sklearn

# %%
from sklearn.decomposition import NMF
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
import pandas as pd

# %% [markdown]
# Sklearn принимает на вход строки, поэтому склеим наши списки.

# %%
stexts = [' '.join(text) for text in texts]

# %% [markdown]
# Сделаем матрицу слова-документы с помощью TfidfVectorizer

# %%
vectorizer = TfidfVectorizer(max_features=25000, min_df=5, max_df=0.3, lowercase=False)
X = vectorizer.fit_transform(stexts)

# %% [markdown]
# Разложим её.

# %%
model = NMF(n_components=30)

# %%
model.fit(X)
# Out:
# NMF(alpha=0.0, beta_loss='frobenius', init=None, l1_ratio=0.0, max_iter=200,
#   n_components=30, random_state=None, shuffle=False, solver='cd',
#   tol=0.0001, verbose=0)

# %%
def get_nmf_topics(model, n_top_words):
    
    #id слов.
    feat_names = vectorizer.get_feature_names()
    
    word_dict = {};
    for i in range(30):
        
        #топ n слов для темы.
        words_ids = model.components_[i].argsort()[:-n_top_words - 1:-1]
        words = [feat_names[key] for key in words_ids]
        word_dict['Topic # ' + '{:02d}'.format(i+1)] = words;
    
    return pd.DataFrame(word_dict);

# %%
get_nmf_topics(model, 10)
# Out:
#          Topic # 01 Topic # 02     Topic # 03  Topic # 04 Topic # 05  \
# 0       программист     return       обучение      сигнал         lt
# 1           продукт   function      нейросеть     частота         gt
# 2         сотрудник        amp       машинный   усилитель        div
# 3  программирование      const    изображение       канал      input
# 4          понимать     import       алгоритм  напряжение       body
# 5            деньга      false      нейронный       связь        std
# 6            думать     string      интеллект    диапазон  компонент
# 7             жизнь     result         модель     антенна         li
# 8            понять     struct  искусственный     станция      class
# 9            знание        int      программа   искажение    элемент
#
#      Topic # 06 Topic # 07      Topic # 08   Topic # 09 Topic # 10  \
# 0    устройство     public           атака  космический      игрок
# 1      смартфон     string    безопасность      спутник       игра
# 2       телефон    private      уязвимость       орбита    игровой
# 3     мобильный      class   злоумышленник       ракета     играть
# 4   аккумулятор     static          пароль      аппарат   персонаж
# 5        гаджет      класс          защита        земля   геймплей
# 6        девайс   override     вредоносный      станция    комната
# 7         умный     return          доступ        полёт      steam
# 8  беспроводный      метод      шифрование       космос     миссия
# 9        датчик     import  информационный      планета      unity
#
#        ...       Topic # 21  Topic # 22  Topic # 23  Topic # 24 Topic # 25  \
# 0      ...           google      объект       рынок     windows     клиент
# 1      ...          android       класс    блокчейн   microsoft     услуга
# 2      ...        мобильный    значение  российский       linux    продукт
# 3      ...          реклама       метод      бизнес      studio     сервис
# 4      ...         firebase     элемент      страна      visual     бизнес
# 5      ...            unity  переменный  технология      server     письмо
# 6      ...           сервис    свойство      деньга       azure     звонок
# 7      ...            apple      строка      россия  обновление   оператор
# 8      ...            store      массив       рубль   программа    продажа
# 9      ...            swift       вызов     миллион     драйвер  интерфейс
#
#        Topic # 26  Topic # 27  Topic # 28 Topic # 29     Topic # 30
# 0            дата      сервер       товар   страница     автомобиль
# 1           центр      запрос      скидка    браузер          tesla
# 2    оборудование      сервис     магазин    элемент    беспилотный
# 3  инфраструктура       пакет  покупатель      текст         машина
# 4          услуга      скрипт     покупка    контент       водитель
# 5        облачный       адрес  распродажа    вкладка      автопилот
# 6          сервер   настройка     продажа    реклама         дорога
# 7       провайдер       домен     пятница     chrome         watson
# 8          облако   сообщение    продавец     кнопка  автомобильный
# 9      охлаждение  сертификат       заказ      экран       грузовик
#
# [10 rows x 30 columns]

# %%
model = NMF(n_components=50, init='nndsvd', solver='mu')
model.fit(X)
get_nmf_topics(model, 10)
# Out:
#          Topic # 01 Topic # 02     Topic # 03  Topic # 04 Topic # 05  \
# 0         сотрудник     return         учёный  устройство         lt
# 1            бизнес   function   исследование      сигнал         gt
# 2       программист      const        научный      датчик        div
# 3            деньга      false    температура     частота      input
# 4  программирование     модуль    университет       плата  компонент
# 5          понимать   значение  исследователь     питание        std
# 6         программа     строка          земля  напряжение       body
# 7           готовый      вызов       животное       режим         li
# 8        инструмент   параметр         теория      корпус      class
# 9            понять        var    поверхность       канал     render
#
#    Topic # 06 Topic # 07      Topic # 08   Topic # 09 Topic # 10  \
# 0     android     public           атака  космический      игрок
# 1      google     string      уязвимость      спутник       игра
# 2    смартфон    private    безопасность       ракета    игровой
# 3   мобильный      class   злоумышленник       орбита     играть
# 4  устройство     static          защита      аппарат   персонаж
# 5       apple      класс     вредоносный        земля   геймплей
# 6     телефон     return      устройство      станция    комната
# 7       экран   override          доступ        полёт      steam
# 8      iphone      метод          пароль       космос     миссия
# 9     samsung      final  информационный    двигатель      unity
#
#         ...             Topic # 21  Topic # 22  Topic # 23  Topic # 24  \
# 0       ...                   дата      объект      сервис     windows
# 1       ...                  центр       класс   сообщение   microsoft
# 2       ...           оборудование       метод    облачный       linux
# 3       ...         инфраструктура    значение  технология      server
# 4       ...                 услуга    свойство    telegram       azure
# 5       ...               облачный     элемент   платформа     браузер
# 6       ...                 облако      массив  мессенджер      visual
# 7       ...             охлаждение  переменный    facebook  обновление
# 8       ...              провайдер    операция       канал   компьютер
# 9       ...                 стойка      person       рынок     драйвер
#
#       Topic # 25  Topic # 26     Topic # 27     Topic # 28    Topic # 29  \
# 0       обучение       товар     автомобиль    виртуальный        клиент
# 1      нейросеть      скидка    беспилотный         машина        звонок
# 2       машинный     магазин          tesla     реальность        услуга
# 3      нейронный  покупатель         машина         vmware         номер
# 4      интеллект  распродажа       водитель        vsphere      оператор
# 5       алгоритм     покупка      автопилот          hyper         вызов
# 6         модель     пятница         дорога  виртуализация     интерфейс
# 7  искусственный       заказ  автомобильный     технология    клиентский
# 8         google    продавец       грузовик         облако     сообщение
# 9    изображение     продажа         motors        сетевой  техподдержка
#
#         Topic # 30
# 0           камера
# 1            видео
# 2         движение
# 3      регистратор
# 4          ivideon
# 5         объектив
# 6         blackvue
# 7  видеонаблюдение
# 8       разрешение
# 9           съёмка
#
# [10 rows x 30 columns]

# %%
model = NMF(n_components=50, init='nndsvdar', solver='mu')
model.fit(X)
get_nmf_topics(model, 10)
# Out:
#          Topic # 01 Topic # 02     Topic # 03   Topic # 04 Topic # 05  \
# 0           продукт     return         учёный   устройство         lt
# 1       программист   function   исследование       сигнал         gt
# 2  программирование      const        научный       датчик        div
# 3          понимать        amp  исследователь        плата      input
# 4            думать      false    университет      частота        std
# 5            понять        var    температура      питание       body
# 6             жизнь        int       животное   напряжение  компонент
# 7            деньга     struct      квантовый        режим         li
# 8            знание      error         теория        канал    элемент
# 9            вообще       else    эксперимент  температура      class
#
#    Topic # 06 Topic # 07      Topic # 08   Topic # 09 Topic # 10  \
# 0     android     public           атака  космический      игрок
# 1   мобильный    private    безопасность      спутник       игра
# 2  устройство     string          защита       орбита    игровой
# 3      дизайн      class   злоумышленник       ракета     играть
# 4       unity     static     вредоносный      аппарат   персонаж
# 5       swift     return      устройство        земля   геймплей
# 6       apple   override       программа      станция    комната
# 7   платформа      класс          пароль        полёт      steam
# 8    дайджест      метод  информационный       космос     миссия
# 9  библиотека      final          ботнет    двигатель    история
#
#         ...         Topic # 21  Topic # 22    Topic # 23  Topic # 24  \
# 0       ...             google      объект      блокчейн     windows
# 1       ...             сервис       класс    технология   microsoft
# 2       ...            аккаунт       метод    транзакция       linux
# 3       ...          поисковый    значение    финансовый      server
# 4       ...         корпорация     элемент     платформа  обновление
# 5       ...             amazon    свойство      биткойна       azure
# 6       ...             chrome       вызов  криптовалюта     драйвер
# 7       ...              cloud  переменный        сервис   программа
# 8       ...          microsoft      массив       bitcoin   компьютер
# 9       ...            реклама    операция    blockchain   платформа
#
#       Topic # 25  Topic # 26      Topic # 27     Topic # 28  Topic # 29  \
# 0       обучение       товар            дата    виртуальный      клиент
# 1      нейросеть      скидка           центр         машина      услуга
# 2       машинный     магазин    оборудование     реальность      бизнес
# 3       алгоритм  покупатель  инфраструктура     технология     продажа
# 4      нейронный     покупка        облачный         vmware    заказчик
# 5         модель  распродажа          услуга         облако   интерфейс
# 6      интеллект     пятница          облако  виртуализация  клиентский
# 7  искусственный    продавец       провайдер        vsphere      сервис
# 8    изображение     продажа      охлаждение          hyper      звонок
# 9  распознавание       заказ          сервис       облачный     продукт
#
#         Topic # 30
# 0           камера
# 1            видео
# 2         движение
# 3      регистратор
# 4          ivideon
# 5         объектив
# 6         blackvue
# 7       фотография
# 8  видеонаблюдение
# 9       разрешение
#
# [10 rows x 30 columns]

# %%
model = NMF(n_components=100, init='nndsvd')
model.fit(X)
get_nmf_topics(model, 10)
# Out:
#       Topic # 01 Topic # 02 Topic # 03     Topic # 04 Topic # 05  Topic # 06  \
# 0         модель         lt  галактика     устройство         gt      кнопка
# 1  моделирование        div     звезда          умный       body       экран
# 2       контекст        std   телескоп         девайс    bitcoin   интерфейс
# 3    архитектура     return     солнце         гаджет    summary      панель
# 4     pocketbook      input  вселенная      мобильный       echo     вкладка
# 5       сознание        int     светов   беспроводный     config     нажатие
# 6  представление         gt   миллиард     управление     script   настройка
# 7    программный         li    млечный         датчик       head      нажать
# 8     предметный      param    планета  производитель       html  клавиатура
# 9        область      class      волна       передача   latitude      иконка
#
#   Topic # 07     Topic # 08   Topic # 09 Topic # 10       ...         \
# 0     public         учёный      аппарат      игрок       ...
# 1    private   исследование        земля       игра       ...
# 2     string  исследователь  космический    игровой       ...
# 3     static        научный       орбита     играть       ...
# 4      class    университет      планета   персонаж       ...
# 5   override       животное      спутник   геймплей       ...
# 6      final         группа     астероид     миссия       ...
# 7     return    эксперимент       миссия    комната       ...
# 8        new     обнаружить  поверхность      steam       ...
# 9      using     социальный    солнечный  противник       ...
#
#        Topic # 21  Topic # 22        Topic # 23    Topic # 24     Topic # 25  \
# 0            дата       класс   порекомендовать       windows       обучение
# 1           центр       метод      предпочитать     microsoft      нейросеть
# 2    оборудование       вызов  профессиональный         linux       машинный
# 3  инфраструктура      string           слушать        server      интеллект
# 4      охлаждение       class      пользоваться         azure      нейронный
# 5          стойка    свойство          менеджер    обновление  искусственный
# 6      мониторинг  реализация            музыка       драйвер       deepmind
# 7       серверный   экземпляр          бумажный  операционный          агент
# 8          воздух       value        заниматься     платформа       алгоритм
# 9    эксплуатация      object           читалка     поддержка         нейрон
#
#    Topic # 26     Topic # 27          Topic # 28     Topic # 29  \
# 0       товар      сотрудник         виртуальный          робот
# 1      скидка        рабочий              машина  робототехника
# 2     магазин         бизнес          реальность         машина
# 3  покупатель   руководитель              vmware         датчик
# 4  распродажа       работник             vsphere      способный
# 5     покупка       менеджер               hyper         рекорд
# 6     пятница  корпоративный       виртуализация         сборка
# 7       заказ       директор          технология       скорость
# 8    продавец       зарплата              oculus         дронов
# 9     продажа         отпуск  производительность         result
#
#         Topic # 30
# 0           камера
# 1            видео
# 2          ivideon
# 3         объектив
# 4  видеонаблюдение
# 5         движение
# 6       разрешение
# 7           съёмка
# 8       аналоговый
# 9            gopro
#
# [10 rows x 30 columns]

# %%
model = NMF(n_components=100, init='nndsvdar')
model.fit(X)
get_nmf_topics(model, 10)
# Out:
#          Topic # 01 Topic # 02   Topic # 03     Topic # 04  Topic # 05  \
# 0       программист         lt      аппарат     устройство       react
# 1  программирование        div        земля          умный   компонент
# 2            знание        std  космический         девайс       props
# 3             навык     return       орбита   беспроводный      render
# 4        математика      input      планета         гаджет         div
# 5            python        int      спутник     управление  компонента
# 6              язык         gt     астероид      мобильный   component
# 7        специалист         li       миссия  производитель    свойство
# 8       технический      param  поверхность       передача      button
# 9           область      class    солнечный       mediatek   состояние
#
#     Topic # 06 Topic # 07     Topic # 08    Topic # 09   Topic # 10  \
# 0     смартфон     public      нейросеть       станция        игрок
# 1       xiaomi    private  распознавание       базовый         игра
# 2  аккумулятор     string       обучение         связь      игровой
# 3      дисплей     static      интеллект       антенна       играть
# 4        экран      class       deepmind         линия       миссия
# 5           гб   override  искусственный         иначе      комната
# 6      телефон      final        научный   космический     персонаж
# 7       lenovo        new          агент       рабочий     геймплей
# 8      планшет     return  исследователь        космос  прохождение
# 9      samsung      using   распознавать  оборудование      предмет
#
#         ...             Topic # 21      Topic # 22        Topic # 23  \
# 0       ...                   дата          объект   порекомендовать
# 1       ...                  центр          модель      предпочитать
# 2       ...           оборудование        свойство  профессиональный
# 3       ...         инфраструктура          person           слушать
# 4       ...             охлаждение          менять      пользоваться
# 5       ...                 стойка   моделирование          менеджер
# 6       ...             мониторинг        астероид            музыка
# 7       ...                 услуга        операция          бумажный
# 8       ...              серверный  местоположение        заниматься
# 9       ...                 воздух         событие           читалка
#
#      Topic # 24     Topic # 25  Topic # 26     Topic # 27          Topic # 28  \
# 0       windows       обучение       товар      сотрудник         виртуальный
# 1     microsoft       машинный      скидка        рабочий              машина
# 2         linux         модель     магазин         бизнес          реальность
# 3        server      нейронный  покупатель   руководитель              vmware
# 4         azure       алгоритм     покупка       менеджер             vsphere
# 5    обновление      интеллект  распродажа       работник               hyper
# 6       драйвер         нейрон     пятница  корпоративный       виртуализация
# 7  операционный  искусственный       заказ       директор  производительность
# 8     поддержка        признак    продавец       зарплата             virtual
# 9     платформа          агент     продажа         отпуск             сетевой
#
#      Topic # 29       Topic # 30
# 0        клиент           камера
# 1        услуга            видео
# 2        бизнес          ivideon
# 3    клиентский         объектив
# 4       продажа  видеонаблюдение
# 5      заказчик         движение
# 6  техподдержка       разрешение
# 7     поддержка           съёмка
# 8           crm       аналоговый
# 9     интерфейс            gopro
#
# [10 rows x 30 columns]

# %% [markdown]
# Лучше всего справилась модель [n_components=100, init='nndsvdar']. Она даже смогла выташить что-то более-менее адекватное из 5 го топика.
# Лучшие топики: 24, 26, 29.
